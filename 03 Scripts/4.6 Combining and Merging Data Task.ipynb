# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Load data

# %%
# define the path and assign dataframes to the "df" variables

path = r'C:\Users\Jakov\2023 Instacart Basket Analysis'

df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_checked.csv'), index_col = 0)
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = 0)
df_ords_prods_comb = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# # 04.

# %%
# check dimensions of the dataframe

df_ords_prods_comb.shape
# Out:
# (32434489, 11)

# %% [markdown]
# # 05., 06.

# %%
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
#delete '_merge column'

df_ords_prods_comb.drop('_merge', axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[6], line 3
#       1 #delete '_merge column'
# ----> 3 df_ords_prods_comb.drop('_merge', axis = 1, inplace = True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
# ...

# %%
df_ords_prods_comb
# Out:
#           order_id  product_id  add_to_cart_order  reordered  user_id  \
# 0                2       33120                  1          1   202279
# 1                2       28985                  2          1   202279
# 2                2        9327                  3          0   202279
# 3                2       45918                  4          1   202279
# 4                2       30035                  5          0   202279
# ...            ...         ...                ...        ...      ...
# 32434484   3421083       39678                  6          1    25247
# 32434485   3421083       11352                  7          0    25247
# 32434486   3421083        4600                  8          0    25247
# 32434487   3421083       24852                  9          1    25247
# 32434488   3421083        5020                 10          1    25247
#
#           order_number  orders_day_of_a_week  order_hour_of_day  \
# ...

# %%
#merge df_ords_prods_comb dataframe with df_prods dataframe with 'product_id' column as a common column

df_ords_prods_merged = df_ords_prods_comb.merge(df_prods, on = 'product_id')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[9], line 3
#       1 #merge df_ords_prods_comb dataframe with df_prods dataframe with 'product_id' column as a common column
# ----> 3 df_ords_prods_merged = df_ords_prods_comb.merge(df_prods, on = 'product_id')
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:10093, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10074 @Substitution("")
#   10075 @Appender(_merge_doc, indents=2)
#   10076 def merge(
#    (...)
#   10089     validate: str | None = None,
#   10090 ) -> DataFrame:
#   10091     from pandas.core.reshape.merge import merge
# > 10093     return merge(
#   10094         self,
#   10095         right,
#   10096         how=how,
#   10097         on=on,
#   10098         left_on=left_on,
# ...

# %%
df_ords_prods_merged
# Out:
#           order_id  product_id  add_to_cart_order  reordered  user_id  \
# 0                2       33120                  1          1   202279
# 1               26       33120                  5          0   153404
# 2              120       33120                 13          0    23750
# 3              327       33120                  5          1    58707
# 4              390       33120                 28          1   166654
# ...            ...         ...                ...        ...      ...
# 32404854   3265099       43492                  3          0   111311
# 32404855   3361945       43492                 19          0   142932
# 32404856   3267201       33097                  2          0   183867
# 32404857   3393151       38977                 32          0    79056
# 32404858   3400803       23624                  7          0   152189
#
#           order_number  orders_day_of_a_week  order_hour_of_day  \
# ...

# %%
df_ords_prods_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# # 07.

# %%
# export newly merged dataframe into pkl file

df_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_with_names_merged.pkl'))

# %%
df_ords_prods_merged.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_ords_prods_merged.shape
#
# NameError: name 'df_ords_prods_merged' is not defined
